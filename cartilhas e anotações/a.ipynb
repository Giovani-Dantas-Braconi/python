# %%
import matplotlib.pyplot as pyplot


vendas = [1500, 2000, 200, 5000, 765, 4569, 3029, 5849, 3333, 8393,]

print(len(vendas))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 import matplotlib.pyplot as pyplot
#       4 vendas = [1500, 2000, 200, 5000, 765, 4569, 3029, 5849, 3333, 8393,]
#       6 print(len(vendas))
#
# ModuleNotFoundError: No module named 'matplotlib'
# ...
#      ---------------------------------------- 0.0/160.8 kB ? eta -:--:--
#      ----------------------------- -------- 122.9/160.8 kB 2.4 MB/s eta 0:00:01
#      ------------------------------------ - 153.6/160.8 kB 1.8 MB/s eta 0:00:01
#      ------------------------------------ - 153.6/160.8 kB 1.8 MB/s eta 0:00:01
#      ------------------------------------ 160.8/160.8 kB 875.1 kB/s eta 0:00:00
# ...
#      ---------------------------------------- 0.0/61.2 kB ? eta -:--:--
#      --------------------------------- ------ 51.2/61.2 kB 2.6 MB/s eta 0:00:01
# ...

# %%
import matplotlib.pyplot as pyplot


vendas = [1500, 2000, 200, 5000, 765, 4569, 3029, 5849, 3333, 8393,]

print(len(vendas))
